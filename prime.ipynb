# %%
m = int(input("Enter m: "))
n = int(input("Enter n: "))

print("Prime numbers:")
for num in range(m, n + 1):
    if num > 1:
        for i in range(2, num):
            if num % i == 0:
                break
        else:
            print(num, end=" ")
# Out:
# Enter m: 1
# Enter n: 5
# Prime numbers:
# 2 3 5
